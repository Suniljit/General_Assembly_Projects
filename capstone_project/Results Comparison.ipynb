# %% [markdown]
# # Default Params

# %% [markdown]
# ![CleanShot 2023-05-15 at 10.15.21.png](attachment:30fe2a4c-03d9-4c5b-a7c1-ce93b7ba88d4.png)

# %% [markdown]
# # Results

# %% [markdown]
# ![CleanShot 2023-05-15 at 11.49.54.png](attachment:a9505ce7-b28d-4a6d-969e-342f4bf6b531.png)

# %% [markdown]
# ![CleanShot 2023-05-15 at 21.39.26.png](attachment:d17089cf-1ff0-4fa0-9a39-a8cb59f00a95.png)

# %% [markdown]
# ![CleanShot 2023-05-16 at 13.34.32.png](attachment:75eb456d-76a4-4f7f-8d19-117c5ef20ec1.png)
